# %%
# %matplotlib inline
import numpy as ap

incomes = ap.random.normal(27000, 15000, 10000)
incomes = ap.append(incomes, [1000000000])

import matplotlib.pyplot as plt
plt.hist(incomes, 50)
plt.show()

# %%
incomes.mean()
# Out:
# 126959.88313034027

# %%
def reject_outliers(data):
    u = np.median(data)
    s = np.std(data)
    filtered = [e for e in data if (u - 2 * s < e < u + 2 * s)]
    return filtered

filtered = reject_outliers(incomes)
plt.hist(filtered, 50)
plt.show()
